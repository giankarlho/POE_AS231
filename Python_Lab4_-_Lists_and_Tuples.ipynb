# %% [markdown]
# <a href="https://www.vallegrande.edu.pe"><img src = "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRIyJUeI5SvesB6z8V3AQo7OkGQXdyh8qvyikcASjTPYPwn08ptVG1Uh_zemOl48Wntaho&usqp=CAU" width = 300, align = "center"></a>
#
# <h1 align=center><font size = 5>Lists and Tuples</font></h1>

# %% [markdown]
# ## Table of Contents
#
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <li><a href="#ref1">Lists</a></li>
# <li><a href="#ref2">Tuples</a></li>
# </div>
# <hr>

# %% [markdown]
# <hr>

# %% [markdown]
# <a id="ref1"></a>
# <center><h1>Lists</h1></center>
#
# First of all, we're gonna take a look at lists in Python. A list is a sequenced collection of different objects of Python, such as integers, strings, and other lists as well. The address of each element within a list is called an index. An index is used to access and refer to elements within a list.

# %% [markdown]
# <a ><img src = "https://ibm.box.com/shared/static/eln445fv5nzv3wlm4u8dnfhbrcrv0hff.png" width = 1000, align = "center"></a>
#   <h4 align=center> Representación de una lista
#
#
#
#   </h4>

# %% [markdown]
#  To create a list just type the list within square brackets **[ ]** with your content inside the parenthesis and separated by commas. Let’s try it!

# %%
album1_info = ["Michael Jackson", "Thriller", 1982, "00:42:19", "Pop, Rock, R&B", 46.0, 65, "30-Nov-82", None, 10.0]              
album1_info

# %%
# Agregando valores a la lista
album1_info.append('Presidente')
album1_info

# %%
album1_info.insert(1,'Tongo')
album1_info

# %%
album1_info.insert(-2,'Carmencita Lara')
album1_info

# %% [markdown]
# You can also create a list from a tuple using the **list** type function as shown below.

# %%
album_tuple = ("Michael Jackson", "Thriller", 1982, "00:42:19","Pop, Rock, R&B", 46.0, 65, "30-Nov-82", None, 10.0) 
album1_list = list(album_tuple)

# %% [markdown]
# En el código anterior, la variable album_tuple contiene una lista de 10 objetos, que son una cadena, un valor numérico y un vector de cadenas. Fácil, ¿eh? Sin embargo, debe recordar que una lista se puede cambiar pero una tupla no. Usando la función **lista** anterior, se crea una nueva lista. Cualquier cambio realizado en **`album1_list`** anterior no hará que cambien los valores de **`album_tuple`**. Ahora imprimamos el contenido de la lista. Sólo tenemos que llamar a su nombre.

# %%
album1_list

# %% [markdown]
# A list has a sequence and each element of a list has a position in that sequence, which starts from 0.

# %% [markdown]
# ### Accessing items in a list
# It is possible to retrieve only a part of a list using the **single square  bracket**  operator **[ ]**. This operator can be also used to get a single element in a specific position. Take a look at the next example:

# %% [markdown]
# The index number 2 returns the third element of a list, if that element exists, because indexing starts at 0:

# %%
album1_list[2]

# %% [markdown]
#  This is shown in figure 1:

# %% [markdown]
# <a ><img src = "https://ibm.box.com/shared/static/ud1hra6uiqel76ih185ao15g1tlf7cgx.png" width = 1100, align = "center"></a>
#   <h4 align=center> Figure 1: Element corresponding to index number 2
#
#
#   </h4>

# %% [markdown]
# Or you can select a part or interval of elements of a list. In our next example we are retrieving the 1st and  2nd elements,this is somtime called **slicing**:

# %%
album1_list[0:2]

# %% [markdown]
#  <a ><img src = "https://ibm.box.com/shared/static/b8311mapjlkyi5w6hl6s3evi4sdlep0l.png" width = 1100, align = "center"></a>
#   <h4 align=center> Figure 2: Selecting index 0 through 1
#
#   </h4>

# %% [markdown]
# It's also possible to find the index of an element using the index method. For example you can find the index of "Thriller" as follows:

# %%
album1_list.index("Thriller")

# %% [markdown]
#  <a ><img src = "https://ibm.box.com/shared/static/ls9rtp24l60ryuwh1o7akdk2588kwv7e.png" width = 1100, align = "center"></a>
#   <h4 align=center> Figure 3: Obtain index corresponding to element “Thriller”
#
#
#   </h4>

# %% [markdown]
# #### 1) Find the value stored at index 4 of album1_list

# %% [markdown]
#  <div align="right">
# <a href="#q2" class="btn btn-default" data-toggle="collapse">Click here for the solution</a>
# </div>
# <div id="q2" class="collapse">
# ```
# album1_list[4]
#
#
# ```
# </div>

# %% [markdown]
# #### 2) Retrieve the elements stored at index 3,4, and 5 of album1_list

# %% [markdown]
#  <div align="right">
# <a href="#q3" class="btn btn-default" data-toggle="collapse">Click here for the solution</a>
# </div>
# <div id="q3" class="collapse">
# ```
# album1_list[3:5]
#
# ```

# %% [markdown]
# Lists are mutable, so you can remove items from them. For example, if you want to remove the item `'thriller`', use the following line of code: `“album1_list.remove('Thriller')”`

# %% [markdown]
#  Lets compare the list before and after:

# %%
album1_list

# %%
album1_list.remove('Thriller')
album1_list

# %% [markdown]
# ### Concatenating lists
#
# Concatenation is the process of putting things together, in sequence. Just use the ** + ** operator, as shown in Figure 4.

# %% [markdown]
#  <a ><img src = "https://ibm.box.com/shared/static/hekpo7kngf2xlh1o3pchetn4eno3mgwa.png" width = 1100, align = "center"></a>
#   <h4 align=center> Figure 4: Concatenation  of two strings
#
#
#
#   </h4>

# %% [markdown]
# Take a look at the next example code:

# %%
album_titles1 = ["Thriller", "Back in Black"]

album_titles2 = ["The Dark Side of the Moon", "The Bodyguard"]

# %%
album_titles1 + album_titles2

# %% [markdown]
# #### 3) Concatenate the following lists A=[1,'a'] abd B=[2,1,'d']

# %% [markdown]
#  <div align="right">
# <a href="#q4" class="btn btn-default" data-toggle="collapse">Click here for the solution</a>
# </div>
# <div id="q4" class="collapse">
# ```
# A=[1,'a']
# B=[2,1,'d']
# A+B
# ```

# %%
x = [1, 'a', 2, 'b',"VamosPerú", True]
type(x)

# %%
miLista=["manzana", 'mango']
miLista[3]

# %%
primero=miLista[3]
print(primero)

# %%
print(miLista[-2])

# %%
print(miLista[1:3])
# Out:
# ['pera', 'uva']

# %%
miLista=["manzana", 'pera','uva', 'mango','piña']
miLista[1:]

# %%
# miLista=["manzana", 'pera','uva', 'mango']
# miLista[0:3]
miLista[:3]

# %%
miLista[:-2]

# %%
otraLista = miLista[0] + ' ' + miLista[2] + str(9)
otraLista

# %% [markdown]
# ##### Use the in operator to check if something is inside a list.

# %%
8 in [1, 2, 3, 16, 98]
# Out:
# False

# %%
16 in [1, 2, 3, 16 ,98]
# Out:
# True

# %% [markdown]
# #### Agregar elementos a la lista
# miLista=["manzana", 'pera','uva', 'mango','piña']

# %%
# Con append agrego un valor al final de la lista
miLista.append("papaya")
print(miLista)

# %%
miLista.append("pitahaya")
print(miLista)

# %%
# Con insert agrego un valor en el índice que se asigne de la lista
miLista.insert(6,"melon")
print(miLista)

# %%
miLista.insert(2,"coco")
miLista

# %%
# Borrar por un valor de la lista
miLista.remove("pera")
print(miLista)

# %%
# Borrar por el indice
del miLista[3]
print(miLista)

# %%
# borrar el último elemento de la lista
miLista=["manzana", 'pera','uva', 'mango']
del miLista[-1]
miLista

# %%
#Copy
miListaCopia = miLista.copy()
print(miListaCopia)

# %%
# sort() me permite ordenar la lista
print(miLista)
miLista.sort()
print("Luego de ordenar la lista:")
print(miLista)

# %%
len(miLista)
# Out:
# 3

# %%
verduras = ["papa","camote","poro","choclo"]
frutas = ["pera","piña","mango","coco"]

#"Compré: papa, choclo, mango y pera"

# %%
print("Compré: ", verduras[0], ", ",   verduras[-1], ", ",    frutas[2] , " y ",    frutas[-1])

# %%
miLista.index("piña")

# %%
# count('valor') permite contar la cantidad de valores en la lista
miLista.append('mango')
print(miLista)
print("La cantidad de mango es: " + str(miLista.count("mango")))

# %%
miLista=['manzana', 'pera', 'uva', 'sandia', 'aguacate']
for x in miLista:
    print(x)

# %%
# Use `+` to concatenate lists.
[1,2] + [3,4] + ["Hola"] + ['Lapadula'] + [True, False]

# %%
miListaNueva=['sandía', 'plátano']
miTotalLista = miLista + miListaNueva
miTotalLista

# %%
# Use `*` to repeat lists.
[1]*3

# %% [markdown]
# <a id="ref2"></a>
# <center><h2>Tuples</h2></center>
#
# **Tuples** are similar to lists, but the data cannot be changed. Tuples elements are also accessed using indexing. It would be good to store the music genres in tuples because they do not change very often.
#
# Here are some examples of tuples in Python:

# %%
genres_tuple = ("pop", "rock", "soul", "hard rock", "soft rock", \
                "R&B", "progressive rock", "disco") 
genres_tuple

# %% [markdown]
# To get the length of a tuple, that is, the number of elements, use the length function, like this:

# %%
len(genres_tuple)

# %% [markdown]
#  we can visualize this in figure 5

# %% [markdown]
#  <a ><img src = "https://ibm.box.com/shared/static/n4969qbta8hhsycs2dc4n8jqbf062wdw.png" width = 1100, align = "center"></a>
#   <h4 align=center> Figure 5:Number of elements in the tuple “genres_tuple”
#
#
#
#
#   </h4>

# %% [markdown]
# You can access a specific element , the value of index 3 is “hard rock ” as illustrated in figure 6

# %% [markdown]
#  <a ><img src = "https://ibm.box.com/shared/static/s6r8v2uy6wifmaqv53w6adabqci47zme.png" width = 1100, align = "center"></a>
#   <h4 align=center> Figure 6: accessing the element at index 3 of “genres_tuple”
#
#   </h4>

# %% [markdown]
#  the code is given by:

# %%
genres_tuple[3]

# %% [markdown]
# Like lists You can get multiple elements by slicing  Index 3:6:

# %%
genres_tuple[3:6]

# %% [markdown]
#  This corresponds to elements in index’s 3 to 5

# %% [markdown]
# <a ><img src = "https://ibm.box.com/shared/static/nqo84vydw6eixdex0trybuvactcw7ffi.png" width = 1100, align = "center"></a>
#   <h4 align=center> Figure 7: Slicing the tuple “genres_tuple”
#
#   </h4>

# %% [markdown]
# #### 5) Find the first two elements of the tuple "genres_tuple"

# %% [markdown]
#  <div align="right">
# <a href="#q5" class="btn btn-default" data-toggle="collapse">Click here for the solution</a>
# </div>
# <div id="q5" class="collapse">
# ```
# genres_tuple[0:2]
#
# ```

# %% [markdown]
# You can get the index of a tuple by coding the value using the index function, like this:

# %%
genres_tuple.index("R&B")

# %% [markdown]
# Finding the index corresponding to the element “R&B”  :

# %% [markdown]
# <a ><img src = "https://ibm.box.com/shared/static/nqo84vydw6eixdex0trybuvactcw7ffi.png" width = 1100, align = "center"></a>
#   <h4 align=center> Figure 7: Finding the index corresponding to the element “R&B” :
#
#   </h4>

# %% [markdown]
# Note that you cannot sort tuples. If you try, you will get an error.

# %% [markdown]
# #### 6) Find the first index of 'disco'

# %%
genres_tuple.index("disco")

# %% [markdown]
#  <div align="right">
# <a href="#q6" class="btn btn-default" data-toggle="collapse">Click here for the solution</a>
# </div>
# <div id="q6" class="collapse">
# ```
# genres_tuple.index("disco")
#
# ```

# %% [markdown]
# You can create a list from a tuple like this:

# %%
genres_list = list(genres_tuple) 
genres_list

# %% [markdown]
# Now you can sort the list:

# %%
genres_list.sort() 
genres_list

# %% [markdown]
# You can't directly sort a tuple, because that would be modifying it, and tuples are immutable. However, the above method, as well as the **`sorted`** function below, can be used to create a sorted list from a given a tuple. For example:

# %%
x = (1, 'a', 2, 'b')
type(x)

# %%
miTupla=(3,4)
otraTupla= 4,6

print(miTupla)
print(otraTupla)

# %%
x, y= 1, 2
x, y= x+y, x*y 
print(x,y)

# %% [markdown]
# <hr>

# %% [markdown]
# #### 1) Create a tuple A_tuple, with the following elements 1, “hello”, [1,2,3 ] and True.

# %% [markdown]
# <div align="right">
# <a href="#q1" class="btn btn-default" data-toggle="collapse">Click here for the solution</a>
# </div>
# <div id="q1" class="collapse">
# ```
# A_tuple=(1, 'hello', [1,2,3 ] , True)
# A_tuple
#
# ```
# </div>

# %% [markdown]
# #### 2) Generate a sorted List from the Tuple C_tuple=(-5,1,-3)

# %% [markdown]
#  <div align="right">
# <a href="#q7" class="btn btn-default" data-toggle="collapse">Click here for the solution</a>
# </div>
# <div id="q7" class="collapse">
# ```
# C_tuple = (-5,1,-3)
# C_list = sorted(C_tuple)
# C_list
#
# ```

# %% [markdown]
# #### 3)  Why wont the command `genres_tuple.remove('pop')` work?

# %% [markdown]
# <div align="right">
# <a href="#q9" class="btn btn-default" data-toggle="collapse">Click here for the solution</a>
# </div>
# <div id="q9" class="collapse">
# ```
# The command wont work because tuples are immutable
#
#
# ```

# %% [markdown]
# ## Lists in lists
#
#
# Lists can consist of scalars (namely numbers) and elements of a much more complex structure (you've already seen such examples as strings, booleans, or even other lists in the previous Section Summary lessons). Let's have a closer look at the case where a list's elements are just lists.
#
# We often find such arrays in our lives. Probably the best example of this is a chessboard.
#
# A chessboard is composed of rows and columns. There are eight rows and eight columns. Each column is marked with the letters A through H. Each line is marked with a number from one to eight.
#
# The location of each field is identified by letter-digit pairs. Thus, we know that the bottom left corner of the board (the one with the white rook) is A1, while the opposite corner is H8.
#
# Let's assume that we're able to use the selected numbers to represent any chess piece. We can also assume that every row on the chessboard is a list.
#
# Look at the code below:

# %% [markdown]
# #### The snippet produces a ten-element list filled with squares of ten integer numbers starting from zero (0, 1, 4, 9, 16, 25, 36, 49, 64, 81)

# %%
squares = [x ** 2 for x in range(10)]

# %% [markdown]
# #### The snippet creates an eight-element array containing the first eight powers of two (1, 2, 4, 8, 16, 32, 64, 128)

# %%
twos = [2 ** i for i in range(8)]

# %% [markdown]
# ##### The snippet makes a list with only the odd elements of the squares list.

# %%
odds = [x for x in squares if x % 2 != 0 ]

# %%
temps = [[0.0 for h in range(24)] for d in range(31)]
#
# The matrix is magically updated here.
#
 
hot_days = 0
 
for day in temps:
    if day[11] > 20.0:
        hot_days += 1
 
print(hot_days, "days were hot.")
# Out:
# 0 days were hot.

# %%
rooms = [[[False for r in range(20)] for f in range(15)] for t in range(3)]

# %%
rooms[1][9][13] = True
rooms[0][4][1] = False

# %% [markdown]
# ### **1. List comprehension**
#
# allows you to create new lists from existing ones in a concise and elegant way. The syntax of a list comprehension looks as follows:
#
#  [expression for element in list if conditional]

# %% [markdown]
# #### which is actually an equivalent of the following code:

# %% [markdown]
# for element in list:
#     if conditional:
#         expression

# %% [markdown]
# #### Here's an example of a list comprehension ‒ the code creates a five-element list filled with with the first five natural numbers raised to the power of 3:

# %%
cubed = [num ** 3 for num in range(5)]
print(cubed) # outputs: [0, 1, 8, 27, 64]
# Out:
# [0, 1, 8, 27, 64]

# %% [markdown]
# ![a6f8b0aeb5d930c150505e4866501b82f1ba8750.png](attachment:a6f8b0aeb5d930c150505e4866501b82f1ba8750.png)

# %%
# A four-column/four-row table ‒ a two dimensional array (4x4)

table = [[":(", ":)", ":(", ":)"],
         [":)", ":(", ":)", ":)"],
         [":(", ":)", ":)", ":("],
         [":)", ":)", ":)", ":("]]

print(table)
print(table[0][0])  # outputs: ':('
print(table[0][3])  # outputs: ':)'
# Out:
# [[':(', ':)', ':(', ':)'], [':)', ':(', ':)', ':)'], [':(', ':)', ':)', ':('], [':)', ':)', ':)', ':(']]
# :(
# :)

# %%
# Cube - a three-dimensional array (3x3x3)

cube = [[[':(', 'x', 'x'],
         [':)', 'x', 'x'],
         [':(', 'x', 'x']],

        [[':)', 'x', 'x'],
         [':(', 'x', 'x'],
         [':)', 'x', 'x']],

        [[':(', 'x', 'x'],
         [':)', 'x', 'x'],
         [':)', 'x', 'x']]]

print(cube)
print(cube[0][0][0])  # outputs: ':('
print(cube[2][2][0])  # outputs: ':)'
# Out:
# [[[':(', 'x', 'x'], [':)', 'x', 'x'], [':(', 'x', 'x']], [[':)', 'x', 'x'], [':(', 'x', 'x'], [':)', 'x', 'x']], [[':(', 'x', 'x'], [':)', 'x', 'x'], [':)', 'x', 'x']]]
# :(
# :)

# %% [markdown]
# ### About the Authors:
#
# Copyright &copy; 2021 Monitor: Giancarlo Valencia Sotomayor gvalencia@vallegrande.edu.pe 😎
